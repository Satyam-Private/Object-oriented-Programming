# %%
import numpy as np

# %%
matrix1 = np.matrix([[1, 2, 3], [4, 5, 6], [7, 8, 9]])

# %%
matrix1
# Out:
# matrix([[1, 2, 3],
#         [4, 5, 6],
#         [7, 8, 9]])

# %%
matrix2 = np.matrix([[1, 2, 3], [4, 5, 6], [7, 8, 9]])

# %%
# operations in matrix add , substract  , multiply , dot product , inverse , transpse

# %%
matrix1 + matrix2
# Out:
# matrix([[ 2,  4,  6],
#         [ 8, 10, 12],
#         [14, 16, 18]])

# %%
np.add(matrix1 , matrix2)
# Out:
# matrix([[ 2,  4,  6],
#         [ 8, 10, 12],
#         [14, 16, 18]])

# %%
matrix1 - matrix2
# Out:
# matrix([[0, 0, 0],
#         [0, 0, 0],
#         [0, 0, 0]])

# %%
np.subtract(matrix1 , matrix2)
# Out:
# matrix([[0, 0, 0],
#         [0, 0, 0],
#         [0, 0, 0]])

# %%
np.dot(matrix1 , matrix2)
#dot product of matrix1 and matrix2
# Out:
# matrix([[ 30,  36,  42],
#         [ 66,  81,  96],
#         [102, 126, 150]])

# %%
np.multiply(matrix1 , matrix2) # element wise multiplication
# Out:
# matrix([[ 1,  4,  9],
#         [16, 25, 36],
#         [49, 64, 81]])
